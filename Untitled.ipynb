# %%
api_key= 'AIzaSyDqMY4K67Xi_dKjowMNIqOp9HU2eQ0CD3I'

# %%
# !pip install --upgrade google-api-python-client

# %%
from googleapiclient.discovery import build
from IPython.display import JSON
import json
import pandas as pd

# %%
channels_id=['UCSUf5_EPEfl4zlBKZHkZdmw',# Danny Gonzalez
            'UC7zsxKqd5MicTf4VhS9Y74g', # Kurtis Conner
            'UCTSRIY3GLFYIpkR2QwyeklA', # Drew Gooden
            'UCpmvp5czsIrQHsbqya4-6Jw', # Chad Chad
            'UCoLUji8TYrgDy74_iiazvYA', # Jarvis Johnson
            'UCfp86n--4JvqKbunwSI2lYQ', # Cody Ko
#             'UCnTr3rLQySAokkQjXbduk7Q', # nickisnotgreen
            'UCnmGIkw-KdI0W5siakKPKog', # Ryan Trahan
            'UCuo9VyowIT-ljA5G2ZuC6Yw', # Eddy Burback
            'UCoo-9GEm2mpyYIXSptrKIpA', # 2 Danny 2 Furious
#             'UCuTQDPUE12sy7g1xf1LAdTA', # Noel Miller    
            'UC0aSHiQNMy8IMmS7_8WbtdA', # FunkyFrogBait
#             'UCKGMrHJRXyM_WmPKS-lvE2A', # Casey Aonso
            ]

# %%
# api_service_name = "youtube"
# api_version = "v3"

# youtube =build(api_service_name, api_version, developerKey=api_key)
# request = youtube.channels().list( part="snippet,contentDetails,statistics",forUsername="MrBeast")
# response = request.execute()

# JSON(response)

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def channel_stats(channels_id, youtube):
    
    all_data = []
    request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id=",".join(channels_id)
    )
    response = request.execute()
    response_str = json.dumps(response, indent=4)
    
#   loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscriberCount': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads'],
               }
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %% [markdown]
# ## Channel Statistics
#
# Let's take a look at the channel statistics using the channel_stats function defined below.

# %%
channel_stats = channel_stats(channels_id, youtube)
channel_stats
# Out:
#          channelName subscriberCount       views totalVideos  \
# 0      FunkyFrogBait          631000    43858107          89
# 1  2 Danny 2 Furious         1980000   131680958          62
# 2        Drew Gooden         3980000   752813581         143
# 3      Kurtis Conner         4440000   706978980         216
# 4       Eddy Burback         1480000   110285782          80
# 5          Chad Chad         1970000   152221468          57
# 6     Jarvis Johnson         1960000   228129084         144
# 7     Danny Gonzalez         6150000  1389713784         277
# 8        Ryan Trahan        12700000  2066939448         276
# 9            Cody Ko         5990000  1482211391         395
#
#                  playlistId
# 0  UU0aSHiQNMy8IMmS7_8WbtdA
# 1  UUoo-9GEm2mpyYIXSptrKIpA
# 2  UUTSRIY3GLFYIpkR2QwyeklA
# 3  UU7zsxKqd5MicTf4VhS9Y74g
# 4  UUuo9VyowIT-ljA5G2ZuC6Yw
# 5  UUpmvp5czsIrQHsbqya4-6Jw
# 6  UUoLUji8TYrgDy74_iiazvYA
# 7  UUSUf5_EPEfl4zlBKZHkZdmw
# 8  UUnmGIkw-KdI0W5siakKPKog
# 9  UUfp86n--4JvqKbunwSI2lYQ

# %%
channel_stats['subscriberCount'] = pd.to_numeric(channel_stats['subscriberCount'])
channel_stats['views'] = pd.to_numeric(channel_stats['views'])
channel_stats['totalVideos'] = pd.to_numeric(channel_stats['totalVideos'])

# %%
channel_stats['viewsPerVideo'] = ((channel_stats['views']/channel_stats['totalVideos']).round(2))

# %%
channel_stats.sort_values(['viewsPerVideo'], ascending= False)
# Out:
#          channelName  subscriberCount       views  totalVideos  \
# 8        Ryan Trahan         12700000  2066939448          276
# 2        Drew Gooden          3980000   752813581          143
# 7     Danny Gonzalez          6150000  1389713784          277
# 9            Cody Ko          5990000  1482211391          395
# 3      Kurtis Conner          4440000   706978980          216
# 5          Chad Chad          1970000   152221468           57
# 1  2 Danny 2 Furious          1980000   131680958           62
# 6     Jarvis Johnson          1960000   228129084          144
# 4       Eddy Burback          1480000   110285782           80
# 0      FunkyFrogBait           631000    43858107           89
#
#                  playlistId  viewsPerVideo
# 8  UUnmGIkw-KdI0W5siakKPKog     7488911.04
# 2  UUTSRIY3GLFYIpkR2QwyeklA     5264430.64
# 7  UUSUf5_EPEfl4zlBKZHkZdmw     5017017.27
# 9  UUfp86n--4JvqKbunwSI2lYQ     3752433.90
# 3  UU7zsxKqd5MicTf4VhS9Y74g     3273050.83
# 5  UUpmvp5czsIrQHsbqya4-6Jw     2670552.07
# 1  UUoo-9GEm2mpyYIXSptrKIpA     2123886.42
# 6  UUoLUji8TYrgDy74_iiazvYA     1584229.75
# 4  UUuo9VyowIT-ljA5G2ZuC6Yw     1378572.28
# 0  UU0aSHiQNMy8IMmS7_8WbtdA      492787.72

# %%
channel_stats["playlistId"][4]
# Out:
# 'UUuo9VyowIT-ljA5G2ZuC6Yw'

# %%
# now lets get all the video id from the channel using the playlist id
def get_video_ids(youtube, playlist_id):


    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId= playlist_id,
        maxResults = 50
    )
    response = request.execute()
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
#   to get all the vidIds since maax is 50 we will implement next_page_token
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
# get video statistics of all the given videoIds
def get_video_stats(youtube, video_ids):
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    return pd.DataFrame(all_video_info)

# %%
def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %%
# Create a dataframe with video statistics and comments from all channels

video_df = pd.DataFrame()
comments_df = pd.DataFrame()

for c in channel_stats['channelName'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = channel_stats.loc[channel_stats['channelName']== c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
    # get video data
    video_data = get_video_stats(youtube, video_ids)
    # get comment data
    comments_data = get_comments_in_videos(youtube, video_ids)

    # append video data together and comment data toghether
    video_df = pd.concat([video_df, video_data], ignore_index=True)
    comments_df = pd.concat([comments_df, comments_data], ignore_index=True)
# Out:
# Getting video information from channel: FunkyFrogBait
# Could not get comments for video kWT7Hw12qpo
# Could not get comments for video dC8DFl1PVLw
# Could not get comments for video 4TXaepMn3Is
# Could not get comments for video sQAazvPEbvs
# Could not get comments for video OzosMcJJyt8
# Could not get comments for video KCQzEbpYmrI
# Could not get comments for video kmp6q2_YkMI
# Could not get comments for video 6nIYQaad0dw
# Getting video information from channel: 2 Danny 2 Furious
# Could not get comments for video 99kb2Tt05sw
# Getting video information from channel: Drew Gooden
# Could not get comments for video hhSYpPSnfww
# Could not get comments for video iWowyqDCiD0
# Getting video information from channel: Kurtis Conner
# Getting video information from channel: Eddy Burback
# Getting video information from channel: Chad Chad
# Getting video information from channel: Jarvis Johnson
# Could not get comments for video kMJabsfGIZc
# Getting video information from channel: Danny Gonzalez
# Could not get comments for video 97eB8JqZvgM
# Getting video information from channel: Ryan Trahan
# Could not get comments for video Le5aOAmjHVU
# Could not get comments for video BQ0T59bqIcM
# Could not get comments for video JHPn8M6mBis
# Getting video information from channel: Cody Ko
# Could not get comments for video GN98kvw0aYw

# %%
comments_df
# Out:
#          video_id                                           comments
# 0     OlErnPszQ5k  [Just an FYI Dr Sean Baker got his medical lic...
# 1     qz9EW79QPmU  [Unfortunately Kelly’s behavior after I finish...
# 2     buF2OLe_Ejg  [Make no mistake spiderverse was made for mone...
# 3     hfKTzbwCO6s  [Hey guys! Just wanted to clarify here that th...
# 4     K1HCVNXgK98  [You can really taste the water sofener in my ...
# ...           ...                                                ...
# 1718  D34Rg1QitAo  [Codys personality is now the other guy sugges...
