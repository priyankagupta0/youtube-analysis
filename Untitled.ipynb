# %% [markdown]
# # Exploratory Data Analyses On Youtube Video Data from My Favorite Youtube Channels.
#
# ## Data limitations
# The dataset is a real-world dataset and suitable for the research. However, the selection of only my favorite Youtube channels to include in the research might not be accurate. My definition is "popular" is only based on subscriber count but there are other metrics that could be taken into consideration as well (e.g. views, engagement).
#
# ## Ethics of data source
# According to Youtube API's guide (https://developers.google.com/youtube/v3/getting-started), the usage of Youtube API is free of charge given that your application send requests within a quota limit. "The YouTube Data API uses a quota to ensure that developers use the service as intended and do not create applications that unfairly reduce service quality or limit access for others. " The default quota allocation for each application is 10,000 units per day, and you could request additional quota by completing a form to YouTube API Services if you reach the quota limit.
#
# Since all data requested from Youtube API is public data (which everyone on the Internet can see on Youtube), there is no particular privacy issues as far as I am concerned. In addition, the data is obtained only for research purposes in this case and not for any commercial interests.

# %%
api_key= 'AIzaSyDqMY4K67Xi_dKjowMNIqOp9HU2eQ0CD3I'

# %%
# !pip install --upgrade google-api-python-client

# %%
# Google API
from googleapiclient.discovery import build
from IPython.display import JSON
import json
import pandas as pd
import isodate

# %%
from dateutil import parser

# Data visualization libraries
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns
sns.set(style="darkgrid", color_codes=True)

# %%
# NLP libraries
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.sentiment import SentimentIntensityAnalyzer
from wordcloud import WordCloud

# %%
channels_id=['UCSUf5_EPEfl4zlBKZHkZdmw',# Danny Gonzalez
            'UC7zsxKqd5MicTf4VhS9Y74g', # Kurtis Conner
            'UCTSRIY3GLFYIpkR2QwyeklA', # Drew Gooden
            'UCpmvp5czsIrQHsbqya4-6Jw', # Chad Chad
            'UCoLUji8TYrgDy74_iiazvYA', # Jarvis Johnson
            'UCfp86n--4JvqKbunwSI2lYQ', # Cody Ko
#             'UCnTr3rLQySAokkQjXbduk7Q', # nickisnotgreen
            'UCnmGIkw-KdI0W5siakKPKog', # Ryan Trahan
            'UCuo9VyowIT-ljA5G2ZuC6Yw', # Eddy Burback
            'UCoo-9GEm2mpyYIXSptrKIpA', # 2 Danny 2 Furious
#             'UCuTQDPUE12sy7g1xf1LAdTA', # Noel Miller    
            'UC0aSHiQNMy8IMmS7_8WbtdA', # FunkyFrogBait
#             'UCKGMrHJRXyM_WmPKS-lvE2A', # Casey Aonso
            ]

# %%
# api_service_name = "youtube"
# api_version = "v3"

# youtube =build(api_service_name, api_version, developerKey=api_key)
# request = youtube.channels().list( part="snippet,contentDetails,statistics",forUsername="MrBeast")
# response = request.execute()

# JSON(response)

# %%
api_service_name = "youtube"
api_version = "v3"

# Get credentials and create an API client
youtube = build(
    api_service_name, api_version, developerKey=api_key)

# %%
def channel_stats(channels_id, youtube):
    
    all_data = []
    request = youtube.channels().list(
    part="snippet,contentDetails,statistics",
    id=",".join(channels_id)
    )
    response = request.execute()
    response_str = json.dumps(response, indent=4)
    
#   loop through items
    for item in response['items']:
        data = {'channelName': item['snippet']['title'],
                'subscriberCount': item['statistics']['subscriberCount'],
                'views': item['statistics']['viewCount'],
                'totalVideos': item['statistics']['videoCount'],
                'playlistId': item['contentDetails']['relatedPlaylists']['uploads'],
               }
        all_data.append(data)
        
    return(pd.DataFrame(all_data))

# %% [markdown]
# ## **Channel Statistics
#
# Let's take a look at the channel statistics using the channel_stats function defined below We'll take a look at their channels as a whole.

# %%
channel_stats = channel_stats(channels_id, youtube)
# Converting string columns to numeric 
channel_stats['subscriberCount'] = pd.to_numeric(channel_stats['subscriberCount'])
channel_stats['views'] = pd.to_numeric(channel_stats['views'])
channel_stats['totalVideos'] = pd.to_numeric(channel_stats['totalVideos'])

# %%
channel_stats.sort_values(['subscriberCount'], ascending= False)
# Out:
#          channelName  subscriberCount       views  totalVideos  \
# 7        Ryan Trahan         12700000  2073284292          276
# 9     Danny Gonzalez          6150000  1391056233          277
# 8            Cody Ko          5990000  1482819058          395
# 2      Kurtis Conner          4450000   708869506          216
# 4        Drew Gooden          3980000   753309107          143
# 1          Chad Chad          1980000   153081634           57
# 6  2 Danny 2 Furious          1980000   131859149           62
# 3     Jarvis Johnson          1970000   228221875          144
# 5       Eddy Burback          1480000   110419005           80
# 0      FunkyFrogBait           642000    44941239           89
#
#                  playlistId
# 7  UUnmGIkw-KdI0W5siakKPKog
# 9  UUSUf5_EPEfl4zlBKZHkZdmw
# 8  UUfp86n--4JvqKbunwSI2lYQ
# 2  UU7zsxKqd5MicTf4VhS9Y74g
# 4  UUTSRIY3GLFYIpkR2QwyeklA
# 1  UUpmvp5czsIrQHsbqya4-6Jw
# 6  UUoo-9GEm2mpyYIXSptrKIpA
# 3  UUoLUji8TYrgDy74_iiazvYA
# ...

# %%
channel_stats['viewsPerVideo'] = ((channel_stats['views']/channel_stats['totalVideos']).round(2))

# %%
channel_stats.sort_values(['viewsPerVideo'], ascending= False)
# Out:
#          channelName  subscriberCount       views  totalVideos  \
# 7        Ryan Trahan         12700000  2073284292          276
# 4        Drew Gooden          3980000   753309107          143
# 9     Danny Gonzalez          6150000  1391056233          277
# 8            Cody Ko          5990000  1482819058          395
# 2      Kurtis Conner          4450000   708869506          216
# 1          Chad Chad          1980000   153081634           57
# 6  2 Danny 2 Furious          1980000   131859149           62
# 3     Jarvis Johnson          1970000   228221875          144
# 5       Eddy Burback          1480000   110419005           80
# 0      FunkyFrogBait           642000    44941239           89
#
#                  playlistId  viewsPerVideo
# 7  UUnmGIkw-KdI0W5siakKPKog     7511899.61
# 4  UUTSRIY3GLFYIpkR2QwyeklA     5267895.85
# 9  UUSUf5_EPEfl4zlBKZHkZdmw     5021863.66
# 8  UUfp86n--4JvqKbunwSI2lYQ     3753972.30
# 2  UU7zsxKqd5MicTf4VhS9Y74g     3281803.27
# ...

# %% [markdown]
#  Interestingly, some channels have more subscribers but less views and vice versa. For example, Danny's and Cody Ko's channels has significantly more subscribers than Drew Gooden's channel, but slightly less average views.

# %% [markdown]
# Similarly chad chad and Jarvis has the same amount of subscribers but chad chad has significantly less videos uploaded. Quite interesting.

# %%
# Lets plot some graphs

sns.set(rc={'figure.figsize':(10,8)})

ax= sns.barplot(y= 'subscriberCount', x= 'channelName', data = channel_stats.sort_values('subscriberCount', ascending=False))
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)  # Rotate the x-axis labels by 45 degrees
ax.set_title('subscribes visualization of each channel')
ax.yaxis.set_major_formatter(ticker.FuncFormatter(lambda x, pos: '{:,.2f}'.format(x/1000000) + 'M'))
plt.show()

# %% [markdown]
# ## Form functions to get the video details and comments

# %%
# now lets get all the video id from the channel using the playlist id
def get_video_ids(youtube, playlist_id):


    request = youtube.playlistItems().list(
        part="snippet,contentDetails",
        playlistId= playlist_id,
        maxResults = 50
    )
    response = request.execute()
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
#   to get all the vidIds since maax is 50 we will implement next_page_token
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

# %%
# get video statistics of all the given videoIds
def get_video_stats(youtube, video_ids):
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelTitle', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
    return pd.DataFrame(all_video_info)

# %%
def get_comments_in_videos(youtube, video_ids):
    all_comments = []
    for video_id in video_ids:
        try:   
            request = youtube.commentThreads().list(
                part="snippet,replies",
                videoId=video_id
            )
            response = request.execute()
        
            comments_in_video = [comment['snippet']['topLevelComment']['snippet']['textOriginal'] for comment in response['items'][0:10]]
            comments_in_video_info = {'video_id': video_id, 'comments': comments_in_video}

            all_comments.append(comments_in_video_info)
            
        except: 
            # When error occurs - most likely because comments are disabled on a video
            print('Could not get comments for video ' + video_id)
        
    return pd.DataFrame(all_comments)

# %%
# Create a dataframe with video statistics and comments from all channels

video_df = pd.DataFrame()
comments_df = pd.DataFrame()

for c in channel_stats['channelName'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = channel_stats.loc[channel_stats['channelName']== c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
    # get video data
    video_data = get_video_stats(youtube, video_ids)
    # get comment data
    comments_data = get_comments_in_videos(youtube, video_ids)

    # append video data together and comment data toghether
    video_df = pd.concat([video_df, video_data], ignore_index=True)
    comments_df = pd.concat([comments_df, comments_data], ignore_index=True)
# Out:
# Getting video information from channel: FunkyFrogBait
# Could not get comments for video kWT7Hw12qpo
# Could not get comments for video dC8DFl1PVLw
# Could not get comments for video 4TXaepMn3Is
# Could not get comments for video sQAazvPEbvs
# Could not get comments for video OzosMcJJyt8
# Could not get comments for video KCQzEbpYmrI
# Could not get comments for video kmp6q2_YkMI
# Could not get comments for video 6nIYQaad0dw
# Getting video information from channel: Chad Chad
# Getting video information from channel: Kurtis Conner
# Getting video information from channel: Jarvis Johnson
# Could not get comments for video kMJabsfGIZc
# Getting video information from channel: Drew Gooden
# Could not get comments for video iWowyqDCiD0
# Getting video information from channel: Eddy Burback
# Getting video information from channel: 2 Danny 2 Furious
# Could not get comments for video 99kb2Tt05sw
# Getting video information from channel: Ryan Trahan
# ...

# %%
comments_df
# Out:
#          video_id                                           comments
# 0     OlErnPszQ5k  [I eat hamburgers but I season and use a marin...
# 1     qz9EW79QPmU  [Unfortunately Kelly’s behavior after I finish...
# 2     buF2OLe_Ejg  [Haven't watched the new one yet but gt has co...
# 3     hfKTzbwCO6s  [Hey guys! Just wanted to clarify here that th...
# 4     K1HCVNXgK98  [I won't do it if it's not bottled water. But ...
# ...           ...                                                ...
# 1719  GD43C6CvdVQ  [My best friend 8 Bit Bulbasaur is exactly lik...
# 1720  qvMOO4-JSeg  [hey ummm... were u in louisiana when u filmed...
# 1721  WRe_yup6Nw0  [this is literally my favorite Danny Gonzalez ...
# 1722  wtiEuGdHAIo  [Damn danny really went from skinny 13 year ol...
# 1723  PEIy0p2wbKs  [Hey whoever is reading this know that Jesus l...
#
# [1724 rows x 2 columns]

# %%
video_df
# Out:
#          video_id    channelTitle  \
# 0     OlErnPszQ5k   FunkyFrogBait
# 1     qz9EW79QPmU   FunkyFrogBait
# 2     buF2OLe_Ejg   FunkyFrogBait
# 3     hfKTzbwCO6s   FunkyFrogBait
# 4     K1HCVNXgK98   FunkyFrogBait
# ...           ...             ...
# 1735  GD43C6CvdVQ  Danny Gonzalez
# 1736  qvMOO4-JSeg  Danny Gonzalez
# 1737  WRe_yup6Nw0  Danny Gonzalez
# 1738  wtiEuGdHAIo  Danny Gonzalez
# 1739  PEIy0p2wbKs  Danny Gonzalez
#
#                                                   title  \
# 0                           TikTok CARNIVORES are CRAZY
# 1                              TikTok's Biggest GRIFTER
# 2     Across the Spider-Verse is PEAK Animation #shorts
# 3                                 SATAN Shops at Target
# 4            People Who Hate the Taste of Water #shorts
# ...                                                 ...
# 1735        The 9 Friends Everyone Has - Danny Gonzalez
# 1736                           Go Dumb - Danny Gonzalez
# ...

# %% [markdown]
# ## EDA & Feature engineering
# In order to analyze the data effectively, there are a few pre-processing steps that need to be performed. Initially, it is
# important to reformat certain columns, specifically the date and time columns like "publishedAt" and "duration". Additionally, it would be beneficial to enhance the data by incorporating new features that provide valuable insights into the characteristics of the videos.

# %% [markdown]
# ## Check for the null values

# %%
video_df.isnull().any()
# Out:
# video_id          False
# channelTitle      False
# title             False
# description       False
# tags               True
# publishedAt       False
# viewCount         False
# likeCount         False
# favouriteCount     True
# commentCount       True
# duration          False
# definition        False
# caption           False
# dtype: bool

# %%
video_df['commentCount'].isnull().sum()
# Out:
# 11

# %% [markdown]
# There are only 11 videos with no comment, I think we could drop those.

# %%
video_df['commentCount'] = pd.to_numeric(video_df['commentCount'])
video_df['viewCount'] = pd.to_numeric(video_df['viewCount'])
video_df['likeCount'] = pd.to_numeric(video_df['likeCount'])

# %%
video_df = video_df[video_df['commentCount'] != 0]
video_df
# Out:
#          video_id    channelTitle  \
# 0     OlErnPszQ5k   FunkyFrogBait
# 1     qz9EW79QPmU   FunkyFrogBait
# 2     buF2OLe_Ejg   FunkyFrogBait
# 3     hfKTzbwCO6s   FunkyFrogBait
# 4     K1HCVNXgK98   FunkyFrogBait
# ...           ...             ...
# 1735  GD43C6CvdVQ  Danny Gonzalez
# 1736  qvMOO4-JSeg  Danny Gonzalez
# 1737  WRe_yup6Nw0  Danny Gonzalez
# 1738  wtiEuGdHAIo  Danny Gonzalez
# 1739  PEIy0p2wbKs  Danny Gonzalez
#
#                                                   title  \
# 0                           TikTok CARNIVORES are CRAZY
# 1                              TikTok's Biggest GRIFTER
# 2     Across the Spider-Verse is PEAK Animation #shorts
# 3                                 SATAN Shops at Target
# 4            People Who Hate the Taste of Water #shorts
# ...                                                 ...
# 1735        The 9 Friends Everyone Has - Danny Gonzalez
# 1736                           Go Dumb - Danny Gonzalez
# ...

# %%
video_df_copy = video_df.copy()

# %%
video_df_copy.publishedAt.sort_values().value_counts()
# Out:
# 2018-09-21T19:00:03Z    2
# 2018-03-30T20:00:01Z    2
# 2007-09-02T02:27:34Z    1
# 2021-02-27T19:47:16Z    1
# 2021-03-24T17:51:21Z    1
#                        ..
# 2018-07-10T21:00:06Z    1
# 2018-07-10T17:00:06Z    1
# 2018-07-09T22:19:41Z    1
# 2018-07-06T22:08:53Z    1
# 2023-06-16T21:19:26Z    1
# Name: publishedAt, Length: 1733, dtype: int64

# %% [markdown]
# There's no strange dates in the publish date column, videos were published between 2007 and 2023.

# %% [markdown]
# ## Enriching data
# I want to enrich the data for further analyses, for example:
#
# -> create published date column with another column showing the day in the week the video was published, which will be useful for later analysis.
#
# -> convert video duration to seconds instead of the current default string format
#
# -> calculate number of tags for each video
#
# -> calculate comments and likes per 1000 view ratio

# %%
# Create publish day (in the week) column
video_df_copy['publishedAt'] =  video_df_copy['publishedAt'].apply(lambda x: parser.parse(x))
video_df_copy[ 'pushblishDayName'] = video_df_copy['publishedAt'].apply(lambda x: x.strftime("%A"))

# %%
# convert duration to seconds
video_df_copy['durationSecs'] = video_df_copy['duration'].apply(lambda x: isodate.parse_duration(x))
video_df_copy['durationSecs'] = video_df_copy['durationSecs'].astype('timedelta64[s]')

# %%
# Add number of tags
video_df_copy['tagsCount'] = video_df_copy['tags'].apply(lambda x: 0 if x is None else len(x))

# %%
video_df_copy['likeRatio'] = video_df_copy['likeCount'] / video_df_copy['viewCount'] * 1000
video_df_copy['commentRatio'] = video_df_copy['commentCount'] / video_df_copy['viewCount'] * 1000

# %%
# Title character length
video_df_copy['titleLength'] = video_df_copy['title'].apply(lambda x: len(x))

# %%
video_df_copy.head()
# Out:
#       video_id   channelTitle  \
# 0  OlErnPszQ5k  FunkyFrogBait
# 1  qz9EW79QPmU  FunkyFrogBait
# 2  buF2OLe_Ejg  FunkyFrogBait
# 3  hfKTzbwCO6s  FunkyFrogBait
# 4  K1HCVNXgK98  FunkyFrogBait
#
#                                                title  \
# 0                        TikTok CARNIVORES are CRAZY
# 1                           TikTok's Biggest GRIFTER
# 2  Across the Spider-Verse is PEAK Animation #shorts
# 3                              SATAN Shops at Target
# 4         People Who Hate the Taste of Water #shorts
#
#                                          description  \
# 0  Go to my sponsor https://aura.com/funkyfrog to...
# 1  I love the smell of rainbows burning in the mo...
# 2
# 3  Happy Pride my dastardly minions of darkness.....
# 4
#
#                                                 tags  \
# 0  [tiktok, drama, reaction, react, commentary, c...
# 1  [tiktok, drama, lgbtq, reaction, commentary, c...
# 2                                               None
# ...

# %% [markdown]
# ## Exploratory analysis
#
# ### Views distribution per channel
#
# Having obtained the video statistics for all channels, we can now examine how views are distributed across each channel. This allows us to identify patterns in the viewership of their videos.
# Some channels may have a significant number of views for a particular video while their other videos receive comparatively fewer views. On the other hand, certain channels may exhibit a more evenly distributed viewership across their videos. Upon analyzing the data, it becomes evident that Ryan Trahan, Cody Ko, and Danny experience a substantial variation in their views, indicating the presence of a few viral videos. In contrast, FunkyFrogBait, Eddy and Chad Chad may have a lower overall view count, but their views are more consistent across their videos.

# %% [markdown]
# ###### About violinplot-
# A violin plot would provide you with a visual representation of this distribution. Each "violin" in the plot represents a category or group (in this case, a YouTube channel). The width of the violin at different points along its length represents the density or frequency of views at those values.
#
# In simpler terms, if a part of the violin is wider, it means that more videos from that channel have views in that range. If it's narrower, it means that fewer videos have views in that range. The height of the violin doesn't have a specific meaning; it's mainly used to visualize the shape of the distribution.
#
# The white dot in the middle of each violin represents the median number of views for that channel. The thick black bar inside the violin shows the range where the middle 50% of the views fall (between the 25th and 75th percentiles). The thin lines extending from the violin (called "whiskers") show the minimum and maximum values within a certain range.

# %%
plt.rcParams['figure.figsize'] = (15, 10)
sns.violinplot(x= video_df_copy['channelTitle'], y= video_df_copy['viewCount'], palette= 'pastel')
# Out:
# <AxesSubplot:xlabel='channelTitle', ylabel='viewCount'>

# %% [markdown]
# ### Is the length of a video a significant factor in terms of attracting views and generating engagement, such as likes and comments?}

# %%
sns.histplot(data= video_df_copy[video_df_copy['durationSecs'] < 10000], x= 'durationSecs', bins= 30)
# Out:
# <AxesSubplot:xlabel='durationSecs', ylabel='Count'>

# %% [markdown]
# The histogram presented below illustrates that the majority of videos fall within the range of 600 to 1200 seconds, which is roughly equivalent to 10 to 20 minutes. In order to accommodate exceptionally long videos, such as streaming videos, the duration limit has been set to 10,000 seconds.

# %%
# Now we plot the duration against comment count and like count.
fig, ax =plt.subplots(1,2)
sns.scatterplot(x= video_df_copy['durationSecs'], y =video_df_copy ['commentCount'], ax=ax[0])
sns.scatterplot( x= video_df_copy['durationSecs'], y = video_df_copy['likeCount'], ax=ax[1])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# It can be seen that actually shorter videos tend to get more likes and comments than very long videos.

# %% [markdown]
# ### Is the length of a title a significant factor in terms of attracting views

# %%
sns.scatterplot(data = video_df_copy, x = "titleLength", y = "viewCount")
# Out:
# <AxesSubplot:xlabel='titleLength', ylabel='viewCount'>

# %% [markdown]
# Based on the scatterplot below, there isn't a distinct correlation between title length and views. However, it is worth noting that the majority of highly-viewed videos tend to have an average title length ranging from 5 to 15 characters.

# %% [markdown]
# ## Wordcloud for words in title

# %% [markdown]
# To explore the content and prevalent terms used in creators' video titles, I plan to generate a wordcloud highlighting the most frequently occurring words. Before creating the wordcloud, it is necessary to eliminate common stopwords and others that do not significantly contribute to the overall meaning of the titles.

# %%
video_df_copy['title'] = video_df_copy['title'].astype(str)

# %%
stop_words = set(stopwords.words('english'))
video_df_copy['title_no_stopwords'] = video_df_copy['title'].apply(lambda x: ' '.join([item for item in str(x).split() if item.lower() not in stop_words]))

# %%
video_df_copy['title_no_stopwords'] = video_df_copy['title_no_stopwords'].astype(str)

# %%
video_df_copy
# Out:
#          video_id    channelTitle  \
# 0     OlErnPszQ5k   FunkyFrogBait
# 1     qz9EW79QPmU   FunkyFrogBait
# 2     buF2OLe_Ejg   FunkyFrogBait
# 3     hfKTzbwCO6s   FunkyFrogBait
# 4     K1HCVNXgK98   FunkyFrogBait
# ...           ...             ...
# 1735  GD43C6CvdVQ  Danny Gonzalez
# 1736  qvMOO4-JSeg  Danny Gonzalez
# 1737  WRe_yup6Nw0  Danny Gonzalez
# 1738  wtiEuGdHAIo  Danny Gonzalez
# 1739  PEIy0p2wbKs  Danny Gonzalez
#
#                                                   title  \
# 0                           TikTok CARNIVORES are CRAZY
# 1                              TikTok's Biggest GRIFTER
# 2     Across the Spider-Verse is PEAK Animation #shorts
# 3                                 SATAN Shops at Target
# 4            People Who Hate the Taste of Water #shorts
# ...                                                 ...
# 1735        The 9 Friends Everyone Has - Danny Gonzalez
# 1736                           Go Dumb - Danny Gonzalez
# ...

# %%
words = ' '.join(video_df_copy['title_no_stopwords'])

# %%
wordcloud.generate(words) #this was important
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# I was expecting them to use "Tiktok" the most but seeing it in wordcloud was still pretty cool. They also frequently used words like "Movie", "Day", "Survived", "Cringe", and "Jake Paul" etc.

# %% [markdown]
# ### Number of tags vs views
# Let's plot a scatterplot to check the relation between tags and views.

# %%
sns.scatterplot(x=video_df_copy.tagsCount, y=video_df_copy.viewCount)
plt.xlabel('Tags Count')
plt.ylabel('View Count')
plt.title('Scatter Plot of Tags Count vs. View Count')
plt.show()

# %% [markdown]
# From the above scatterplot we can see that most viewed videos has about two tags, and most of the videos has 0 to 30 tags.

# %% [markdown]
# ## Which day in the week are most videos uploaded?

# %%
day_df = pd.DataFrame(video_df_copy['pushblishDayName'].value_counts())
weekdays = [ 'Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
day_df = day_df.reindex(weekdays)
ax = day_df.reset_index().plot.bar(x='index', y='pushblishDayName', rot=0)

# %% [markdown]
# It is intriguing to observe that a higher number of videos are posted on Fridays, while the weekend, especially Sunday sees fewer uploads. Alternatively, it could indicate that many creators dedicate their time to video production over the weekend or during the week and choose to release their content at on Fridays.

# %% [markdown]
# ## Wordcloud for video comments

# %% [markdown]
# Now lets explore the kind of words used by commenters!

# %%
stop_words = set(stopwords.words("english"))
comments_df['comments_no_stopwords'] = comments_df['comments'].apply(lambda x: ' '.join([word for word in str(x).split() if word.lower() not in stop_words]))

# %%
# Combine all words into a single string
words = ' '.join(comments_df['comments_no_stopwords'])

# Create a WordCloud object
wordcloud = WordCloud(width=800, height=400, background_color='black', random_state=42)

# Generate the word cloud
wordcloud.generate(words)

# Display the word cloud using matplotlib
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# We can see that next to the obvious words such as "video", "one", the most frequent words are quite positive, such as "love", "think", "look". A lot of comments also use their names like "Danny", "Ryan", "Cody".

# %% [markdown]
# ## Summary and Suggestions for Future Research:
#
# This project aimed to investigate video data from the top 9 Data Science/Data Analyst channels and has yielded intriguing findings that can benefit individuals starting a YouTube channel in data science or any other field. The conclusions drawn and potential areas for future research are as follows:
#
# 1. Video Interaction: A correlation was observed between the number of likes/comments and video views, suggesting that higher engagement contributes to increased viewership. However, it is essential to recognize that this correlation does not necessarily imply causation, as the relationship can work both ways. Likes appeared to be a stronger indicator of interaction than comments, and the number of likes seemed to follow the concept of "social proof" – more views leading to more likes.
#
# 2. Video Tags: Most videos analyzed contained between 5 and 30 tags. Further exploration could focus on the optimal number and relevance of tags to enhance video visibility and discoverability.
#
# 3. Title Length: Analysis revealed that most-viewed videos tended to have average title lengths ranging from 30 to 70 characters. It suggests that excessively short or long titles may have a negative impact on viewership. Investigating the relationship between title length and video performance in other content categories could provide valuable insights.
#
# 4. Upload Patterns: The study identified a trend of videos being frequently uploaded on Mondays and Fridays, with fewer uploads during weekends. This observation could be explored further to understand the dynamics of content creation and audience preferences across different days of the week.
#
# 5. Comment Sentiment and Market Gaps: Overall, the comments analyzed displayed a positive sentiment, with frequent usage of terms like "please," indicating potential market gaps that creators could address. Conducting sentiment analysis on a larger scale and exploring common themes or unanswered questions within comment threads could offer valuable information for content development and audience engagement.
#
# ### Limitations of the Project:
#
# It is crucial to interpret the findings with caution due to the following limitations:
#
# 1. Small Dataset: The dataset used in this project comprised only around 3,700 videos, which may not fully represent the diversity and breadth of content available on YouTube. Expanding the dataset to include a more extensive range of videos could provide a more comprehensive analysis.
#
# 2. Limited Comment Analysis: The analysis focused on the first 10 comments of each video, which might not be fully representative of all comments. Considering a larger sample of comments or implementing advanced natural language processing techniques could yield deeper insights.
#
# 3. Unaccounted Factors: Various unexplored factors, such as creators' marketing strategies and random effects, may influence video success. Considering additional variables in the analysis, such as promotion tactics or collaborations, could enhance the understanding of video performance.
#
# Future research should address these limitations and delve into a more extensive dataset, comprehensive comment analysis, and inclusion of additional influential factors to gain a more comprehensive understanding of YouTube video dynamics and success factors.

# %% [markdown]
# ### Possible directions for future research:
#
# To further advance and enhance this research project, potential areas to explore include:
#
# 1. Dataset Expansion: Incorporate data from smaller channels within the data science niche to gain a more comprehensive understanding of the trends and patterns across various channel sizes.
#
# 2. Sentiment Analysis: Perform sentiment analysis on the comments to examine the level of positivity or negativity associated with different videos. This analysis can provide insights into which videos receive more positive feedback and which videos attract less positive comments.
#
# 3. Market Research: Analyze the questions within the comment threads to identify common inquiries or gaps in the market. This information can help identify areas where potential content or services could be developed to meet the needs of the viewers.
#
# 4. Comparative Analysis: Extend the research to other niches such as vlogs or beauty channels to compare and contrast different content categories. By investigating various niches, it becomes possible to identify divergent viewership patterns and video characteristics across different genres.
#
# References/ Resources Used:
#
# [1] Thu Vu Data Analytics: https://youtu.be/D56_Cx36oGY
#
# [2] YouTube API: A valuable resource for accessing YouTube data and information. Available at: https://developers.google.com/youtube/v3
#
# [3] Converting Video Durations: Information and guidance on converting video durations using the YouTube API. Source: https://stackoverflow.com/questions/15596753/how-do-i-get-video-durations-with-youtube-api-version-3
#
# [4] Covington, P., Adams, J., Sargin, E. (2016). The YouTube Video Recommendation System. In Proceedings of the Fourth ACM Conference on Recommender Systems (RecSys '16), pp. 191-198, New York, NY, USA: ACM.
